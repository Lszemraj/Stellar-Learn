# %% [markdown]
# # Learning JaxPM

# %%
# !pip install --quiet --upgrade jax
# !pip install --quiet jaxpm

# %%
pip install --upgrade jaxpm
# Out:
# Requirement already satisfied: jaxpm in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (0.0.2)
# Collecting jaxpm
#   Using cached jaxpm-0.1.5-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: jax_cosmo in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jaxpm) (0.1.0)
# Requirement already satisfied: jax>=0.4.30 in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jaxpm) (0.6.1)
# Requirement already satisfied: jaxdecomp>=0.2.2 in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jaxpm) (0.2.7)
# Requirement already satisfied: jaxlib<=0.6.1,>=0.6.1 in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jax>=0.4.30->jaxpm) (0.6.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jax>=0.4.30->jaxpm) (0.5.1)
# Requirement already satisfied: numpy>=1.25 in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jax>=0.4.30->jaxpm) (2.2.6)
# Requirement already satisfied: opt_einsum in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jax>=0.4.30->jaxpm) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jax>=0.4.30->jaxpm) (1.15.3)
# Requirement already satisfied: jaxtyping>=0.2.0 in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jaxdecomp>=0.2.2->jaxpm) (0.3.2)
# Requirement already satisfied: typing-extensions in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jaxdecomp>=0.2.2->jaxpm) (4.12.2)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /home/lszemraj/miniconda3/envs/diffhydro-env/lib/python3.10/site-packages (from jaxtyping>=0.2.0->jaxdecomp>=0.2.2->jaxpm) (0.1.6)
# Using cached jaxpm-0.1.5-py3-none-any.whl (24 kB)
# Installing collected packages: jaxpm
#   Attempting uninstall: jaxpm
#     Found existing installation: jaxpm 0.0.2
#     Uninstalling jaxpm-0.0.2:
#       Successfully uninstalled jaxpm-0.0.2
# Successfully installed jaxpm-0.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import jax
print("Available devices:", jax.devices())
# Out:
# Available devices: [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3), CudaDevice(id=4), CudaDevice(id=5), CudaDevice(id=6), CudaDevice(id=7)]

# %%
import sys
print("sys.executable =", sys.executable)
# Out:
# sys.executable = /home/lszemraj/miniconda3/envs/diffhydro-env/bin/python

# %%
import os
#using GPU, comment out if on CPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '6' #change to the GPU you want to use

# %%
import jax
import jax.numpy as jnp
import jax_cosmo as jc
import jaxpm

from jax.experimental.ode import odeint

from jaxpm.painting import cic_paint
from jaxpm.pm import linear_field, lpt, make_ode_fn

# %%
mesh_shape = [128, 128, 128]
box_size = [128., 128., 128.]
snapshots = jnp.array([0.1, 0.5, 1.0])

@jax.jit
def run_simulation(omega_c, sigma8):
    # Create a small function to generate the matter power spectrum
    k = jnp.logspace(-4, 1, 128)
    pk = jc.power.linear_matter_power(jc.Planck15(Omega_c=omega_c, sigma8=sigma8), k)
    pk_fn = lambda x: jnp.interp(x.reshape([-1]), k, pk).reshape(x.shape)

    # Create initial conditions and particles
    initial_conditions = linear_field(mesh_shape, box_size, pk_fn, seed=jax.random.PRNGKey(0))
    particles = jnp.stack(jnp.meshgrid(*[jnp.arange(s) for s in mesh_shape]),axis=-1).reshape([-1,3])

    # Initial displacement
    cosmo = jc.Planck15(Omega_c=omega_c, sigma8=sigma8)
    dx, p, f = lpt(cosmo, initial_conditions, particles, a=0.1)

    # Evolve the simulation forward
    res = odeint(make_ode_fn(mesh_shape), [particles + dx, p], snapshots, cosmo, rtol=1e-8, atol=1e-8)

    # Return the simulation volume at requested timesteps
    return initial_conditions ,  particles + dx , res[0]

# %%
initial_conditions , lpt_particles , ode_particles = run_simulation(0.25, 0.8)

# %%
from jaxpm.plotting import plot_fields_single_projection # only works in versions 0.1._

fields = {"Initial Conditions" : initial_conditions , "LPT Field" : jnp.log10(cic_paint(jnp.zeros(mesh_shape) ,lpt_particles) + 1)}
for i , field in enumerate(ode_particles[1:]):
    fields[f"field_{i}"] = jnp.log10(cic_paint(jnp.zeros(mesh_shape) , field)+1)
plot_fields_single_projection(fields)
